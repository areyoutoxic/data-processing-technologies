# %% [markdown]
# # Pandas

# %% [markdown]
# Материалы:
# * Макрушин С.В. "Лекция 2: Библиотека Pandas"
# * https://pandas.pydata.org/docs/user_guide/index.html#
# * https://pandas.pydata.org/docs/reference/index.html
# * Уэс Маккини. Python и анализ данных

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Загрузите данные из файла `sp500hst.txt` и обозначьте столбцы в соответствии с содержимым: `"date", "ticker", "open", "high", "low", "close", "volume"`.

# %% [markdown]
# 2. Рассчитайте среднее значение показателей для каждого из столбцов c номерами 3-6.

# %% [markdown]
# 3. Добавьте столбец, содержащий только число месяца, к которому относится дата.

# %% [markdown]
# 4. Рассчитайте суммарный объем торгов для для одинаковых значений тикеров.

# %% [markdown]
# 5. Загрузите данные из файла sp500hst.txt и обозначьте столбцы в соответствии с содержимым: "date", "ticker", "open", "high", "low", "close", "volume". Добавьте столбец с расшифровкой названия тикера, используя данные из файла `sp_data2.csv` . В случае нехватки данных об именах тикеров корректно обработать их.

# %% [markdown]
# ## Лабораторная работа №2

# %% [markdown]
# ### Базовые операции с `DataFrame`

# %% [markdown]
# 1.1 В файлах `recipes_sample.csv` и `reviews_sample.csv` находится информация об рецептах блюд и отзывах на эти рецепты соответственно. Загрузите данные из файлов в виде `pd.DataFrame` с названиями `recipes` и `reviews`. Обратите внимание на корректное считывание столбца с индексами в таблице `reviews` (безымянный столбец).

# %%
import pandas as pd
DFRecipes = pd.read_csv('recipes_sample.csv')
DFReviews = pd.read_csv('reviews_sample.csv')
recipes = pd.DataFrame(DFRecipes)
reviews = pd.DataFrame(DFReviews)

# %%
#переименовать безымяный столбец
reviews.rename(columns = {'Unnamed: 0':'index'}, inplace = True )

# %% [markdown]
# 1.2 Для каждой из таблиц выведите основные параметры:
# * количество точек данных (строк);
# * количество столбцов;
# * тип данных каждого столбца.

# %%
#кол-во строк reviews
reviews_rows = reviews.shape[0]
reviews_rows
# Out:
# 126696

# %%
#кол-во столбцов reviews
reviews.shape[1]
# Out:
# 6

# %%
#тип данных reviews
reviews.dtypes
# Out:
# index         int64
# user_id       int64
# recipe_id     int64
# date         object
# rating        int64
# review       object
# dtype: object

# %%
#кол-во строк recipes
recipes_rows = recipes.shape[0]
recipes_rows
# Out:
# 30000

# %%
#кол-во столбцов reviews
recipes.shape[1]
# Out:
# 8

# %%
#тип данных reviews
recipes.dtypes
# Out:
# name               object
# id                  int64
# minutes             int64
# contributor_id      int64
# submitted          object
# n_steps           float64
# description        object
# n_ingredients     float64
# dtype: object

# %% [markdown]
# 1.3 Исследуйте, в каких столбцах таблиц содержатся пропуски. Посчитайте долю строк, содержащих пропуски, в отношении к общему количеству строк.

# %%
#reviews_null_rows - кол-во пропусков в reviews по столбцам 
#reviews_rows - все строки
reviews_null_rows = reviews.isnull().sum ()
reviews_null_rows
# Out:
# index         0
# user_id       0
# recipe_id     0
# date          0
# rating        0
# review       17
# dtype: int64

# %%
reviews_null_rows / reviews_rows
# Out:
# index        0.000000
# user_id      0.000000
# recipe_id    0.000000
# date         0.000000
# rating       0.000000
# review       0.000134
# dtype: float64

# %%
#recipes_null_rows - кол-во пропусков в recipes по столбцам 
#recipes_rows - все строки
recipes_null_rows = recipes.isnull().sum ()
recipes_null_rows
# Out:
# name                  0
# id                    0
# minutes               0
# contributor_id        0
# submitted             0
# n_steps           11190
# description         623
# n_ingredients      8880
# dtype: int64

# %%
recipes_null_rows / recipes_rows
# Out:
# name              0.000000
# id                0.000000
# minutes           0.000000
# contributor_id    0.000000
# submitted         0.000000
# n_steps           0.373000
# description       0.020767
# n_ingredients     0.296000
# dtype: float64

# %% [markdown]
# 1.4 Рассчитайте среднее значение для каждого из числовых столбцов (где это имеет смысл).

# %%
reviews[['rating']].mean ()
# Out:
# rating    4.410802
# dtype: float64

# %%
recipes[['minutes', 'n_steps', 'n_ingredients']].mean ()
# Out:
# minutes          123.358133
# n_steps            9.805582
# n_ingredients      9.008286
# dtype: float64

# %% [markdown]
# 1.5 Создайте серию из 10 случайных названий рецептов.

# %%
recipes['name'].sample (n=10)
# Out:
# 24932               southern fried chicken w cream gravy
# 19987                      pasta with fresh tomato sauce
# 5845                         chicken marsala with capers
# 14288    huevos revueltos   with prawns and baby spinach
# 22516                         rice and sausage casserole
# 22933            romano s macaroni grill chicken marsala
# 16989                                maple stewed apples
# 16733                                 magic finger jello
# 2266        barbecue  sauce      barbados barbecue sauce
# 11913                          german fresh peach kuchen
# Name: name, dtype: object

# %% [markdown]
# 1.6 Измените индекс в таблице `reviews`, пронумеровав строки, начиная с нуля.

# %%
reviews
# Out:
#           index     user_id  recipe_id        date  rating  \
# 0        370476       21752      57993  2003-05-01       5
# 1        624300      431813     142201  2007-09-16       5
# 2        187037      400708     252013  2008-01-10       4
# 3        706134  2001852463     404716  2017-12-11       5
# 4        312179       95810     129396  2008-03-14       5
# ...         ...         ...        ...         ...     ...
# 126691  1013457     1270706     335534  2009-05-17       4
# 126692   158736     2282344       8701  2012-06-03       0
# 126693  1059834      689540     222001  2008-04-08       5
# 126694   453285  2000242659     354979  2015-06-02       5
# 126695   691207      463435     415599  2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# 2       Very nice breakfast HH, easy to make and yummy...
# ...

# %%
reviews['index'] = reviews.index
reviews
# Out:
#          index     user_id  recipe_id        date  rating  \
# 0            0       21752      57993  2003-05-01       5
# 1            1      431813     142201  2007-09-16       5
# 2            2      400708     252013  2008-01-10       4
# 3            3  2001852463     404716  2017-12-11       5
# 4            4       95810     129396  2008-03-14       5
# ...        ...         ...        ...         ...     ...
# 126691  126691     1270706     335534  2009-05-17       4
# 126692  126692     2282344       8701  2012-06-03       0
# 126693  126693      689540     222001  2008-04-08       5
# 126694  126694  2000242659     354979  2015-06-02       5
# 126695  126695      463435     415599  2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# 2       Very nice breakfast HH, easy to make and yummy...
# ...

# %% [markdown]
# 1.7 Выведите информацию о рецептах, время выполнения которых не больше 20 минут и кол-во ингредиентов в которых не больше 5.

# %%
recipes.loc[(recipes['minutes'] <= 20) & (recipes['n_ingredients'] <= 5)]
# Out:
#                                                     name      id  minutes  \
# 28                                   quick biscuit bread  302399       20
# 60                         peas  fit for a king or queen  303944       20
# 90                     hawaiian sunrise           mimosa  100837        5
# 91            tasty dish s   banana pudding in 2 minutes  286484        2
# 94                                    1 minute meatballs   11361       13
# ...                                                  ...     ...      ...
# 29873  zip and steam red potatoes with butter and garlic  304922       13
# 29874                          ziplock vanilla ice cream   74250       10
# 29905                      zucchini and corn with cheese  256177       15
# 29980               zucchini with jalapeno monterey jack  320622       10
# 29983                          zucchini with serrano ham  162411       15
#
#        contributor_id   submitted  n_steps  \
# ...

# %% [markdown]
# ### Работа с датами в `pandas`

# %% [markdown]
# 2.1 Преобразуйте столбец `submitted` из таблицы `recipes` в формат времени. Модифицируйте решение задачи 1.1 так, чтобы считать столбец сразу в нужном формате.

# %%
recipes.dtypes
# Out:
# name               object
# id                  int64
# minutes             int64
# contributor_id      int64
# submitted          object
# n_steps           float64
# description        object
# n_ingredients     float64
# dtype: object

# %%
recipes['submitted'] = pd.to_datetime(recipes['submitted'])

# %%
recipes.dtypes
# Out:
# name                      object
# id                         int64
# minutes                    int64
# contributor_id             int64
# submitted         datetime64[ns]
# n_steps                  float64
# description               object
# n_ingredients            float64
# dtype: object

# %% [markdown]
# 2.2 Выведите информацию о рецептах, добавленных в датасет не позже 2010 года.

# %%
recipes.loc[(recipes['submitted'] <= '2010/01/01')]
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29993                     zuni caf zucchini pickles  316950     2895
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# ### Работа со строковыми данными в `pandas`

# %% [markdown]
# 3.1  Добавьте в таблицу `recipes` столбец `description_length`, в котором хранится длина описания рецепта из столбца `description`.

# %%
description_length = recipes['description'].str.len()
recipes['description_length'] = description_length
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 3.2 Измените название каждого рецепта в таблице `recipes` таким образом, чтобы каждое слово в названии начиналось с прописной буквы.

# %%
recipes['name'] = recipes['name'].str.capitalize()
recipes
# Out:
#                                                name      id  minutes  \
# 0             George s at the cove  black bean soup   44123       90
# 1                Healthy for them  yogurt popsicles   67664       10
# 2                      I can t believe it s spinach   38798       30
# 3                              Italian  gut busters   35173       45
# 4          Love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie s holey rustic olive and cheddar bread  267661       80
# 29996          Zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   Zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   Zydeco soup  486161       60
# 29999        Cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 3.3 Добавьте в таблицу `recipes` столбец `name_word_count`, в котором хранится количество слов из названии рецепта (считайте, что слова в названии разделяются только пробелами). Обратите внимание, что между словами может располагаться несколько пробелов подряд.

# %%
recipes["name_word_count"] = recipes["name"].str.split().apply(lambda x: len(x))
recipes
# Out:
#                                                name      id  minutes  \
# 0             George s at the cove  black bean soup   44123       90
# 1                Healthy for them  yogurt popsicles   67664       10
# 2                      I can t believe it s spinach   38798       30
# 3                              Italian  gut busters   35173       45
# 4          Love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie s holey rustic olive and cheddar bread  267661       80
# 29996          Zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   Zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   Zydeco soup  486161       60
# 29999        Cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# ### Группировки таблиц `pd.DataFrame`

# %% [markdown]
# 4.1 Посчитайте количество рецептов, представленных каждым из участников (`contributor_id`). Какой участник добавил максимальное кол-во рецептов?

# %%
recipes.groupby('contributor_id'). size ()
# Out:
# contributor_id
# 1530            5
# 1533          186
# 1534           50
# 1535           40
# 1538            8
#              ...
# 2001968497      2
# 2002059754      1
# 2002234079      1
# 2002234259      1
# 2002247884      1
# Length: 8404, dtype: int64

# %%
recipes.groupby('contributor_id'). size ().idxmax()
# Out:
# 89831

# %% [markdown]
# 4.2 Посчитайте средний рейтинг к каждому из рецептов. Для скольких рецептов отсутствуют отзывы? Обратите внимание, что отзыв с нулевым рейтингом или не заполненным текстовым описанием не считается отсутствующим.

# %%
#средний рейтинг к каждому из рецептов.
mean_rating = reviews.groupby(['recipe_id']).agg({'rating': ['mean']})
mean_rating
# Out:
#              rating
#                mean
# recipe_id
# 48         1.000000
# 55         4.750000
# 66         4.944444
# 91         4.750000
# 94         5.000000
# ...             ...
# 536547     5.000000
# 536610     0.000000
# 536728     4.000000
# 536729     4.750000
# 536747     0.000000
#
# [28100 rows x 1 columns]

# %%
#Для скольких рецептов отсутствуют отзывы?
mean_rating['recipe_id'] = mean_rating.index
mean_rating
# Out:
#              rating recipe_id
#                mean
# recipe_id
# 48         1.000000        48
# 55         4.750000        55
# 66         4.944444        66
# 91         4.750000        91
# 94         5.000000        94
# ...             ...       ...
# 536547     5.000000    536547
# 536610     0.000000    536610
# 536728     4.000000    536728
# 536729     4.750000    536729
# 536747     0.000000    536747
#
# [28100 rows x 2 columns]

# %%
reviews_null = pd.concat([reviews,mean_rating]).drop_duplicates(subset = ['recipe_id','recipe_id'], keep=False)
reviews_null_rows = reviews_null.shape[0]
reviews_null_rows
# Out:
# 11932

# %% [markdown]
# 4.3 Посчитайте количество рецептов с разбивкой по годам создания.

# %%
recipes['submitted']= pd.to_datetime(recipes['submitted'])
recipes.dtypes
# Out:
# name                          object
# id                             int64
# minutes                        int64
# contributor_id                 int64
# submitted             datetime64[ns]
# n_steps                      float64
# description                   object
# n_ingredients                float64
# description_length           float64
# name_word_count                int64
# dtype: object

# %%
recipes.loc[:, 'submitted'] = recipes.loc[:, 'submitted'].dt.year
recipes
# Out:
#                                                name      id  minutes  \
# 0             George s at the cove  black bean soup   44123       90
# 1                Healthy for them  yogurt popsicles   67664       10
# 2                      I can t believe it s spinach   38798       30
# 3                              Italian  gut busters   35173       45
# 4          Love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie s holey rustic olive and cheddar bread  267661       80
# 29996          Zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   Zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   Zydeco soup  486161       60
# 29999        Cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193       2002      NaN
# 1               91970       2003      NaN
# ...

# %%
recipes.groupby(['submitted']).agg({'id': ['count']})
# Out:
#              id
#           count
# submitted
# 1999        275
# 2000        104
# 2001        589
# 2002       2644
# 2003       2334
# 2004       2153
# 2005       3130
# 2006       3473
# 2007       4429
# 2008       4029
# 2009       2963
# 2010       1538
# 2011        922
# 2012        659
# 2013        490
# 2014        139
# 2015         42
# 2016         24
# 2017         39
# 2018         24

# %% [markdown]
# ### Объединение таблиц `pd.DataFrame`

# %% [markdown]
# 5.1 При помощи объединения таблиц, создайте `DataFrame`, состоящий из четырех столбцов: `id`, `name`, `user_id`, `rating`. Рецепты, на которые не оставлен ни один отзыв, должны отсутствовать в полученной таблице. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и попытавшись найти строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
df1 = reviews
df2 = recipes
df1.rename(columns = {'recipe_id':'id'}, inplace = True )
df3 = pd.merge(df1, df2)
# Out:
#          index  user_id      id        date  rating  \
# 0            0    21752   57993  2003-05-01       5
# 1        23688    86359   57993  2003-08-10       5
# 2        34842    67026   57993  2005-06-11       5
# 3        42579   371697   57993  2006-10-27       5
# 4        42962   175286   57993  2004-12-29       5
# ...        ...      ...     ...         ...     ...
# 126691  126655   157617   94096  2004-08-14       5
# 126692  126662  1207345  368208  2009-07-13       2
# 126693  126664   357323  154964  2008-10-31       5
# 126694  126675   160974  187418  2007-10-15       5
# 126695  126685    95743  296868  2010-01-02       4
#
#                                                    review  \
# 0       Last week whole sides of frozen salmon fillet ...
# 1       My sisters husband caught a salmon off the Que...
# 2       I enjoyed this very much.  Turned out pretty d...
# 3       Delicious!  Perfect blend of flavors.  I didn'...
# ...

# %%
df4 = df3.dropna(subset=['review'])
df4 = df4.drop(columns=['index', 'date', 'review', 'minutes', 'contributor_id', 'submitted', 'n_steps', 'description', 'n_ingredients', 'description_length', 'name_word_count'])
df4
# Out:
#         user_id      id  rating                                    name
# 0         21752   57993       5                    Salmon with tomatoes
# 1         86359   57993       5                    Salmon with tomatoes
# 2         67026   57993       5                    Salmon with tomatoes
# 3        371697   57993       5                    Salmon with tomatoes
# 4        175286   57993       5                    Salmon with tomatoes
# ...         ...     ...     ...                                     ...
# 126691   157617   94096       5                     Vegetable pasta pie
# 126692  1207345  368208       2                    Crockery pot delight
# 126693   357323  154964       5        Apple cider cheesecake   no cook
# 126694   160974  187418       5                Winter vegetable lasagna
# 126695    95743  296868       4  G nut special sauce and sweet potatoes
#
# [126679 rows x 4 columns]

# %%
df3.loc[(pd.isnull(df3["review"]) == True)]
# Out:
#          index     user_id      id        date  rating review  \
# 2466     96199  2002057405   89207  2018-03-17       5    NaN
# 9901      8881  2001567544    9054  2017-06-03       5    NaN
# 9908     18578  2001508809    9054  2017-04-26       5    NaN
# 9938     55100  2001826405    9054  2017-11-26       5    NaN
# 11172   105206  2001380233  128956  2017-02-05       5    NaN
# 12766    42783  2002060663  107786  2018-03-18       5    NaN
# 21035    53998  2002005298  245231  2018-02-22       5    NaN
# 31447   109590  1803237930   86868  2018-03-20       5    NaN
# 36457    12129  2002120930  167202  2018-04-18       4    NaN
# 52497    33232  2002299388   15553  2018-10-13       4    NaN
# 60484    56197  2001658714  155430  2017-08-05       5    NaN
# 79854    42855  2001346906  522925  2017-01-11       4    NaN
# 82564    21913  2001959957  335709  2018-01-28       5    NaN
# 85304    67973  2001779476    3662  2017-11-05       4    NaN
# ...

# %%
df4.loc[df4['id'] == 8881]
# Out:
# Empty DataFrame
# Columns: [user_id, id, rating, name]
# Index: []

# %% [markdown]
# 5.2 При помощи объединения таблиц и группировок, создайте `DataFrame`, состоящий из трех столбцов: `recipe_id`, `name`, `review_count`, где столбец `review_count` содержит кол-во отзывов, оставленных на рецепт `recipe_id`. У рецептов, на которые не оставлен ни один отзыв, в столбце `review_count` должен быть указан 0. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и найдя строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
df5 = df3.groupby(['id', 'name']).count().reset_index()
df5 = df5.drop(columns=['index', 'date', 'minutes', 'contributor_id', 'submitted', 'n_steps', 'description', 'n_ingredients', 'description_length', 'name_word_count', 'rating'])
df5
# Out:
#            id                                        name  user_id  review
# 0          48                            Boston cream pie        2       2
# 1          55  Betty crocker s southwestern guacamole dip        4       4
# 2          66                 Black coffee barbecue sauce       18      18
# 3          91              Brown rice and vegetable pilaf        4       4
# 4          94                       Blueberry buttertarts        4       4
# ...       ...                                         ...      ...     ...
# 28095  536547                         Cauliflower ceviche        1       1
# 28096  536610               Miracle home made puff pastry        1       1
# 28097  536728                       Gluten free  vegemite        1       1
# 28098  536729                Creole watermelon feta salad        4       4
# 28099  536747                          Lemon pom pom cake        4       4
#
# [28100 rows x 4 columns]

# %% [markdown]
# 5.3. Выясните, рецепты, добавленные в каком году, имеют наименьший средний рейтинг?

# %%
#recipes.groupby(['submitted']).agg({'id': ['count']})
reviews.groupby(['id']).mean(['rating']).reset_index().min()
# Out:
# id           48.0
# index         2.0
# user_id    1533.0
# rating        0.0
# dtype: float64

# %%
recipes['submitted'].loc[recipes['id'] == 48]
# Out:
# 3535    1999
# Name: submitted, dtype: int64

# %% [markdown]
# ### Сохранение таблиц `pd.DataFrame`

# %% [markdown]
# 6.1 Отсортируйте таблицу в порядке убывания величины столбца `name_word_count` и сохраните результаты выполнения заданий 3.1-3.3 в csv файл.

# %%
sorted_df = recipes.sort_values(by='name_word_count', ascending=False)
sorted_df
# Out:
#                                                     name      id  minutes  \
# 26223  Subru uncle s whole green moong dal i ll be ma...   77188       95
# 28083  Tsr version of t g i  friday s black bean soup...  102274       75
# 26222  Subru uncle s toor ki dal sindhi style  dad  m...   76908       65
# 27876  Top secret recipes version of  i h o p  griddl...  113346       20
# 5734   Chicken curry or  cat s vomit on a bed of magg...  294898       30
# ...                                                  ...     ...      ...
# 3253                                          Blackmoons  323195      430
# 4138                                         Bushwhacker  156521       10
# 2357                                            Basbousa   12957       60
# 15052                                          Josefinas  264859       20
# 4710                                            Caramels  143615       30
#
#        contributor_id  submitted  n_steps  \
# ...

# %%
sorted_df.to_csv('file1.csv')

# %% [markdown]
# 6.2 Воспользовавшись `pd.ExcelWriter`, cохраните результаты 5.1 и 5.2 в файл: на лист с названием `Рецепты с оценками` сохраните результаты выполнения 5.1; на лист с названием `Количество отзывов по рецептам` сохраните результаты выполнения 5.2.

# %%
import xlsxwriter

with pd.ExcelWriter('C:\\Users\\marya\\Downloads\\ТОД\\2 лаба\\6.xlsx') as writer:
    df4.to_excel(writer, sheet_name="Рецепты с оценками", index=False)
    df5.to_excel(writer, sheet_name="Количество отзывов по рецептам", index=False)

# %% [markdown]
# #### [версия 2]
# * Уточнены формулировки задач 1.1, 3.3, 4.2, 5.1, 5.2, 5.3
